# %%
import nltk
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
from nltk.corpus import stopwords

# %%
strategy = pd.read_excel("RAW_FCM__Problems_and_Strategies_7.1.2019.xlsx")
strategy.columns = strategy.iloc[1]
strategy = strategy.iloc[2:]

# %%
#strategy.columns

# %%
strategy = strategy.rename(columns={'FCM: GRYD Client ID':'ID',
                                    'Description of targeted problem/issue_703': 'Problem',
                                    'Strategy recommended to address this problem_928':'Strategy',
                                    'Progress made? (select one)_934':'Progress'})
strategy = strategy.loc[:,['ID','Problem','Strategy','Progress']]
strategy = strategy.dropna()

# %%
strategy.head()
# Out:
# 1               ID                                            Problem  \
# 5   77th 1-16-40-2                        wants to expunge her record
# 6   77th 1-16-45-1  needs a job client is a foster kid and her fos...
# 7   77th 1-16-47-2      has poor grades and want to get better grades
# 8   77th 1-16-50-2                    client don't believe in herself
# 13  77th 1-16-64-1  client has a lot of issues he is a foster kid ...
#
# 1                                            Strategy  \
# 5   CM will contact past employers with client to ...
# 6   speak to teacher about mother and refer client...
# 7   CM will work on getting tutoring services alon...
# 8   to mentor client with basic life skills and se...
# 13  referred him to in-house services through SEA ...
#
# 1                              Progress
# 5   Task/Service successfully completed
# 6   Task/Service successfully completed
# 7    N/A - not applicable to this phase
# 8                     A Little progress
# 13                    A Little progress

# %%
len(strategy)
# Out:
# 4039

# %%
df = strategy

# %%
prob_list = df['Problem'].tolist()
prob_list = [s.lower() for s in prob_list]
df['Problem'] = prob_list

# %%
df.Problem.value_counts()
# Out:
# client requested assistance with employment search                                                                                                                   109
# client requires consistent contact from cm/ciw to navagate interpersonal relationships and avoid potential problems with street affiliations                          34
# client requires consistent contact with cm/ciw to navagate interpersonal relationships and avoid potential problems with street affiliations                          33
# peer pressure                                                                                                                                                         25
# anger issues                                                                                                                                                          23
#                                                                                                                                                                     ...
# pessimist                                                                                                                                                              1
# clt is in need of enrollment in an individual therapy service. cm had referred clt to children's hospital therapy services for homeless youth at free of charge.       1
# clients mother has kicked him out. he is in need of housing referrals                                                                                                  1
# client is hanging around with local community members and is using drugs.                                                                                              1
# client requires assitance clearing traffic tickets                                                                                                                     1
# Name: Problem, Length: 2969, dtype: int64

# %%
from string import punctuation
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer

def get_wordnet_pos(word):
    """Map POS tag to first character lemmatize() accepts"""
    tag = nltk.pos_tag([word])[0][1][0].upper()
    tag_dict = {"J": wordnet.ADJ,
                "N": wordnet.NOUN,
                "V": wordnet.VERB,
                "R": wordnet.ADV}

    return tag_dict.get(tag, wordnet.NOUN)

# %%
def normalize(contents):
    
    for i in range (len(contents)):
        contents[i]=contents[i].replace(",", " ")
    all_contents = [''.join([c for c in i if not c.isdigit()]) for i in contents]
    all_contents = [''.join([c for c in i if c not in punctuation]) for i in contents]
        
    lem_texts = []
    lemmatizer = WordNetLemmatizer()
    for i in all_contents:
        lem_texts.append([lemmatizer.lemmatize(w, get_wordnet_pos(w)) for w in nltk.word_tokenize(i)])
    new_texts = [' '.join([c for c in i]) for i in lem_texts] # a list of lemmatized sentences
    
    clean_tokens = list()
    sw = stopwords.words('english')
    other = ['client','clt','ct','need','request','require','want', 'would', 'like',
             '100', '12','week','13','year','14','18','1yr','20','hr','3yr','check',
             '40','50','70','75','80','10','1012','2018','25','community','hour','30']
    sw = sw + other
    for i in range(0,len(new_texts)):
        clean_tokens.append(' '.join([w for w in word_tokenize(new_texts[i]) if w not in sw]))         
    return clean_tokens # a list of sentences without useless words

# %%
normalized_texts = normalize(df['Problem'].tolist())

# %%
pd.set_option('display.max_rows', None, 'display.max_columns', None)
df.head()
# Out:
# 1               ID                                            Problem  \
# 5   77th 1-16-40-2                        wants to expunge her record
# 6   77th 1-16-45-1  needs a job client is a foster kid and her fos...
# 7   77th 1-16-47-2      has poor grades and want to get better grades
# 8   77th 1-16-50-2                    client don't believe in herself
# 13  77th 1-16-64-1  client has a lot of issues he is a foster kid ...
#
# 1                                            Strategy  \
# 5   CM will contact past employers with client to ...
# 6   speak to teacher about mother and refer client...
# 7   CM will work on getting tutoring services alon...
# 8   to mentor client with basic life skills and se...
# 13  referred him to in-house services through SEA ...
#
# 1                              Progress
# 5   Task/Service successfully completed
# 6   Task/Service successfully completed
# 7    N/A - not applicable to this phase
# 8                     A Little progress
# 13                    A Little progress

# %%
tfidf = TfidfVectorizer(min_df=2, max_df=0.8, ngram_range=(1,2))
# features are stored in X
X = tfidf.fit_transform(normalized_texts)

# %%
# feature names
terms = tfidf.get_feature_names()

# %%
terms
# Out:
# ['aa',
#  'aa class',
#  'abandonment',
#  'abide',
#  'abide demand',
#  'ability',
#  'ability stay',
#  'able',
#  'absence',
#  'abuse',
#  'abuse activity',
#  'abuse alcohol',
#  'abuse class',
#  'abuse issue',
#  'abuse problem',
#  'abuse workshop',
#  'academic',
#  'academic attendance',
#  'academic behavior',
#  'academic challenge',
#  'academic motivation',
#  'academic performance',
#  'academic score',
#  'academically',
#  'academy',
#  'access',
#  'access high',
#  'accord',
#  'accord fight',
#  'accord participant',
#  'acquire',
#  'acquire driver',
#  'acquire high',
#  'acquire work',
#  'act',
#  'act impulsively',
#  'act know',
#  'action',
#  'action caught',
#  'action make',
#  'active',
#  'active area',
#  'active gang',
#  'active member',
#  'active negative',
#  'active tag',
#  'activity',
#  'activity know',
#  'activity life',
#  'activity living',
#  'addict',
#  'addiction',
#  'address',
#  'admit',
#  'admit affiliate',
#  'admit drug',
#  'adult',
#  'adult school',
#  'advise',
#  'advisor',
#  'affect',
#  'affected',
#  'affilaitions',
#  'affiliate',
#  'affiliate crew',
#  'affiliate friend',
#  'affiliate gang',
#  'affiliate individual',
#  'affiliate local',
#  'affiliate member',
#  'affiliate peer',
#  'affiliation',
#  'afterschool',
#  'afterschool program',
#  'age',
#  'age enroll',
#  'aggressive',
#  'aggressive parent',
#  'aid',
#  'alcohol',
#  'alcohol often',
#  'alcohol smoke',
#  'alcohol use',
#  'allows',
#  'alone',
#  'along',
#  'along family',
#  'alot',
#  'also',
#  'also influence',
#  'also smoking',
#  'also substance',
#  'altercation',
#  'altercation housematefriend',
#  'always',
#  'among',
#  'angeles',
#  'anger',
#  'anger anger',
#  'anger issue',
#  'anger make',
#  'anger management',
#  'anger managment',
#  'anger problem',
#  'anger towards',
#  'angry',
#  'angry easy',
#  'angry fast',
#  'angry pretty',
#  'angry resentful',
#  'annoyed',
#  'annoyed others',
#  'another',
#  'another school',
#  'antisocial',
#  'antisocial behavior',
#  'antisocial influence',
#  'anxiety',
#  'apartment',
#  'application',
#  'application carls',
#  'application financial',
#  'apply',
#  'apply job',
#  'apply several',
#  'apply snl',
#  'apply summer',
#  'appointment',
#  'area',
#  'area life',
#  'argue',
#  'argues',
#  'around',
#  'around active',
#  'around gryd',
#  'around know',
#  'around local',
#  'around member',
#  'around service',
#  'around work',
#  'arrest',
#  'arrest complete',
#  'arrest due',
#  'arrest try',
#  'art',
#  'art program',
#  'ask',
#  'ask assistance',
#  'ask help',
#  'assault',
#  'assault police',
#  'assess',
#  'assessment',
#  'asset',
#  'assign',
#  'assist',
#  'assist family',
#  'assist home',
#  'assist job',
#  'assist navagate',
#  'assist service',
#  'assistance',
#  'assistance access',
#  'assistance anger',
#  'assistance attain',
#  'assistance baby',
#  'assistance ca',
#  'assistance college',
#  'assistance complete',
#  'assistance credit',
#  'assistance day',
#  'assistance due',
#  'assistance employment',
#  'assistance enrol',
#  'assistance enroll',
#  'assistance explore',
#  'assistance find',
#  'assistance gang',
#  'assistance get',
#  'assistance guard',
#  'assistance hiset',
#  'assistance housing',
#  'assistance item',
#  'assistance job',
#  'assistance locate',
#  'assistance meeting',
#  'assistance navagating',
#  'assistance obtain',
#  'assistance probation',
#  'assistance school',
#  'assistance secure',
#  'assistance seek',
#  'assistance substance',
#  'assistance transportation',
#  'assistance vocational',
#  'assitance',
#  'assitance employment',
#  'assitance program',
#  'associate',
#  'associate local',
#  'associate member',
#  'associate part',
#  'association',
#  'assume',
#  'attain',
#  'attain birth',
#  'attain id',
#  'attain work',
#  'attend',
#  'attend anger',
#  'attend class',
#  'attend college',
#  'attend drug',
#  'attend gryd',
#  'attend high',
#  'attend job',
#  'attend life',
#  'attend organize',
#  'attend school',
#  'attend substance',
#  'attend workshop',
#  'attendance',
#  'attendance attain',
#  'attendance due',
#  'attendance school',
#  'attendance seek',
#  'attends',
#  'attention',
#  'attention education',
#  'attitude',
#  'attitude member',
#  'attitude problem',
#  'attract',
#  'aunt',
#  'aunt cousin',
#  'authority',
#  'automotive',
#  'automotive school',
#  'avoid',
#  'avoid potental',
#  'avoid potential',
#  'avoid problem',
#  'aware',
#  'awareness',
#  'awareness low',
#  'away',
#  'baby',
#  'baby father',
#  'baby supply',
#  'back',
#  'back school',
#  'bad',
#  'bad attitude',
#  'bad behavior',
#  'bad choice',
#  'bad crowd',
#  'bad decision',
#  'bad influence',
#  'bad relationship',
#  'balance',
#  'banger',
#  'barbering',
#  'barbering school',
#  'barrier',
#  'basic',
#  'basis',
#  'basis caught',
#  'basis create',
#  'basis hang',
#  'basis people',
#  'bc',
#  'bc social',
#  'become',
#  'become active',
#  'becomes',
#  'becomes angry',
#  'becomes upset',
#  'behavior',
#  'behavior action',
#  'behavior awareness',
#  'behavior get',
#  'behavior hang',
#  'behavior issue',
#  'behavior problem',
#  'behavior school',
#  'behavior time',
#  'behavior toward',
#  'behavior towards',
#  'behavioral',
#  'behavioral concern',
#  'behavioral issue',
#  'behind',
#  'believe',
#  'belong',
#  'benefit',
#  'benefit mentor',
#  'big',
#  'big issue',
#  'big problem',
#  'bill',
#  'bill food',
#  'biofather',
#  'biomother',
#  'birth',
#  'birth certificate',
#  'blame',
#  'boredom',
#  'born',
#  'boundary',
#  'boundary easy',
#  'boundary friend',
#  'boxing',
#  'boy',
#  'boy currently',
#  'boy drink',
#  'boyfriend',
#  'boyfriend peer',
#  'break',
#  'bring',
#  'bring grade',
#  'brother',
#  'brother influence',
#  'brother negative',
#  'brother sister',
#  'brought',
#  'build',
#  'build self',
#  'building',
#  'building relationship',
#  'buildingupdating',
#  'bullying',
#  'bus',
#  'bus token',
#  'busy',
#  'buy',
#  'ca',
#  'ca dl',
#  'ca id',
#  'caid',
#  'cal',
#  'cal id',
#  'cal tran',
#  'cal work',
#  'calid',
#  'california',
#  'california id',
#  'california identification',
#  'call',
#  'calm',
#  'campus',
#  'campusclient',
#  'campusclient admit',
#  'cant',
#  'cap',
#  'cap gown',
#  'car',
#  'card',
#  'card birth',
#  'card due',
#  'card get',
#  'care',
#  'care daughter',
#  'career',
#  'carls',
#  'carls jr',
#  'carry',
#  'carry grudge',
#  'carry pocket',
#  'case',
#  'case also',
#  'case assault',
#  'case child',
#  'case individual',
#  'case manager',
#  'caught',
#  'caught edible',
#  'caught influence',
#  'caught school',
#  'caught trouble',
#  'caught various',
#  'cause',
#  'cause associate',
#  'cause negative',
#  'cause participant',
#  'cause relapse',
#  'center',
#  'certificate',
#  'certificate california',
#  'certificate social',
#  'challenge',
#  'change',
#  'charge',
#  'child',
#  'child care',
#  'child custody',
#  'child mother',
#  'childrens',
#  'chip',
#  'chip shoulder',
#  'choice',
#  'choice drug',
#  'choice friend',
#  'choice impress',
#  'choice involve',
#  'choice peer',
#  'chooses',
#  'city',
#  'ciw',
#  'ciw assist',
#  'ciw cm',
#  'ciw mentor',
#  'ciw navagate',
#  'ciw work',
#  'ciwcm',
#  'cl',
#  'cl cl',
#  'class',
#  'class help',
#  'class probation',
#  'class take',
#  'class work',
#  'clear',
#  'clear get',
#  'clear ticket',
#  'clearing',
#  'close',
#  'close relationship',
#  'clothes',
#  'clothes school',
#  'clothing',
#  'clts',
#  'cm',
#  'cm assist',
#  'cm ciw',
#  'cm find',
#  'cm met',
#  'cm notice',
#  'cm provide',
#  'cm refer',
#  'cmciw',
#  'cmciw navagate',
#  'college',
#  'college application',
#  'college enroll',
#  'college enrollment',
#  'college token',
#  'college tour',
#  'come',
#  'come home',
#  'come single',
#  'commit',
#  'commitment',
#  'communicate',
#  'communicate well',
#  'communication',
#  'communication family',
#  'communication issue',
#  'communication mother',
#  'communication parent',
#  'communication skill',
#  'compete',
#  'complete',
#  'complete anger',
#  'complete componentsrequirements',
#  'complete diploma',
#  'complete education',
#  'complete high',
#  'complete individual',
#  'complete parent',
#  'complete probation',
#  'complete requirement',
#  'complete service',
#  'complete substance',
#  'compliance',
#  'compliance condition',
#  'compliance get',
#  'compliance school',
#  'compliancy',
#  'compliant',
#  'comply',
#  'comply service',
#  'componentsrequirements',
#  'concern',
#  'concerned',
#  'condition',
#  'condition go',
#  'condition probation',
#  'confidence',
#  'confidence ability',
#  'conflict',
#  'conflict relationship',
#  'congregate',
#  'congregate gang',
#  'connect',
#  'consequence',
#  'consequence action',
#  'consider',
#  'consider danger',
#  'consider low',
#  'consisten',
#  'consisten mentor',
#  'consistent',
#  'consistent contact',
#  'consistent cotnact',
#  'consistent employment',
#  'consistent mentor',
#  'consistent mentoringmotivational',
#  'consistently',
#  'consitent',
#  'consitent contact',
#  'constant',
#  'constantly',
#  'consume',
#  'consume marijuana',
#  'contact',
#  'contact ciw',
#  'contact cmciw',
#  'contact navagate',
#  'content',
#  'contently',
#  'contently school',
#  'continual',
#  'continue',
#  'continue attend',
#  'continue developmental',
#  'continue drink',
#  'continue education',
#  'continue hang',
#  'continue involve',
#  'continue issue',
#  'continue make',
#  'continue stay',
#  'continue struggle',
#  'continue work',
#  'control',
#  'control anger',
#  'cop',
#  'corp',
#  'cotnact',
#  'cotnact cmciw',
#  'could',
#  'counsel',
#  'counsel increase',
#  'counsel little',
#  'counsel mentor',
#  'counsel service',
#  'counsel session',
#  'counsel wrap',
#  'counselingtherapy',
#  'counselor',
#  'court',
#  'court assistance',
#  'court attend',
#  'court case',
#  'court date',
#  'court issue',
#  'court mandate',
#  'court order',
#  'court support',
#  'courtordered',
#  'courtordered complete',
#  'cousin',
#  'create',
#  'create problem',
#  'create resume',
#  'creates',
#  'credit',
#  'credit get',
#  'credit graduate',
#  'credit recovery',
#  'crenshaw',
#  'crew',
#  'crew neighborhood',
#  'crew us',
#  'crime',
#  'criterion',
#  'criticism',
#  'cross',
#  'cross due',
#  'crowd',
#  'culture',
#  'curfew',
#  'current',
#  'current document',
#  'current job',
#  'currently',
#  'currently active',
#  'currently attend',
#  'currently consume',
#  'currently deal',
#  'currently employ',
#  'currently enrol',
#  'currently face',
#  'currently hang',
#  'currently homeless',
#  'currently involve',
#  'currently look',
#  'currently member',
#  'currently open',
#  'currently posse',
#  'currently probation',
#  'currently release',
#  'currently stay',
#  'currently unemployed',
#  'currently use',
#  'currently work',
#  'custody',
#  'custody case',
#  'dad',
#  'daily',
#  'daily basis',
#  'damage',
#  'danger',
#  'danger involve',
#  'dark',
#  'date',
#  'daughter',
#  'day',
#  'day cal',
#  'day care',
#  'daycare',
#  'daycare service',
#  'dcfs',
#  'dcfs case',
#  'deal',
#  'deal low',
#  'decision',
#  'decision make',
#  'decline',
#  'defiant',
#  'defiant behavior',
#  'demand',
#  'demand probation',
#  'demonstrate',
#  'demonstrate poor',
#  'denial',
#  'department',
#  'depression',
#  'desire',
#  'detain',
#  'determine',
#  'develop',
#  'development',
#  'development afterschool',
#  'developmental',
#  'developmental asset',
#  'diaper',
#  'different',
#  'difficult',
#  'difficulty',
#  'difficulty handle',
#  'difficulty home',
#  'difficulty maintain',
#  'difficulty school',
#  'diploma',
#  'diploma currently',
#  'diploma enroll',
#  'diploma ged',
#  'diploma june',
#  'diplomaged',
#  'direct',
#  'direction',
#  'disclose',
#  'discus',
#  'discuss',
#  'disorganize',
#  'display',
#  'disrespect',
#  'disrespectful',
#  'distract',
#  'distract boy',
#  'distraction',
#  'ditch',
#  'dl',
#  'dmv',
#  'dmv id',
#  'doc',
#  'doc get',
#  'doctor',
#  'document',
#  'document assistance',
#  'document birth',
#  'document damage',
#  'document id',
#  'document obtain',
#  'documentation',
#  'doent',
#  'doent attend',
#  'doesnt',
#  'doesnt get',
#  'doesnt know',
#  'doesnt listen',
#  'domestic',
#  'domestic violence',
#  'dont',
#  'dont belong',
#  'dpo',
#  'drink',
#  'drink alcohol',
#  'drink smoke',
#  'drinking',
#  'drinking alcohol',
#  'drinking order',
#  'drinking take',
#  'drive',
#  'drive without',
#  'drive work',
#  'driver',
#  'driver lic',
#  'driver license',
#  'driver permit',
#  'drop',
#  'drop high',
#  'drop school',
#  'drug',
#  'drug abuse',
#  'drug addiction',
#  'drug alcohol',
#  'drug education',
#  'drug marijuana',
#  'drug misuse',
#  'drug occasion',
#  'drug possession',
#  'drug problem',
#  'drug test',
#  'drug use',
#  'due',
#  'due anger',
#  'due family',
#  'due gang',
#  'due hang',
#  'due homeless',
#  'due incident',
#  'due negative',
#  'due parent',
#  'due repetitious',
#  'dv',
#  'earl',
#  'earl jordan',
#  'earn',
#  'earn high',
#  'easily',
#  'easily annoyed',
#  'easily distract',
#  'easily influence',
#  'easily loss',
#  'easily make',
#  'easy',
#  'easy anger',
#  'easy cross',
#  'easy think',
#  'economic',
#  'economic assistance',
#  'edible',
#  'edible inside',
#  'educate',
#  'education',
#  'education assistance',
#  'education class',
#  'education opportunity',
#  'education plan',
#  'education priority',
#  'educational',
#  'educational class',
#  'educational option',
#  'educational program',
#  'educational support',
#  'effect',
#  'else',
#  'email',
#  'emotion',
#  'emotion cause',
#  'emotional',
#  'emotional behavior',
#  'employ',
#  'employer',
#  'employment',
#  'employment application',
#  'employment assist',
#  'employment assistance',
#  'employment attend',
#  'employment cal',
#  'employment complete',
#  'employment counsel',
#  'employment court',
#  'employment family',
#  'employment financial',
#  'employment guard',
#  'employment help',
#  'employment housing',
#  'employment increase',
#  'employment interpersonal',
#  'employment job',
#  'employment lead',
#  'employment opportunity',
#  'employment option',
#  'employment order',
#  'employment refer',
#  'employment resume',
#  'employment school',
#  'employment search',
#  'employment status',
#  'employment stay',
#  'employmentrequested',
#  'employmentrequested assistance',
#  'encourage',
#  'encouragement',
#  'encouragement mentor',
#  'end',
#  'end probation',
#  'enforcement',
#  'engage',
#  'engages',
#  'engages risky',
#  'english',
#  'english class',
#  'english language',
#  'enough',
#  'enough credit',
#  'enrol',
#  'enrol attend',
#  'enrol back',
#  'enrol college',
#  'enrol educational',
#  'enrol high',
#  'enrol new',
#  'enrol school',
#  'enroll',
#  'enroll automotive',
#  'enroll back',
#  'enroll cal',
#  'enroll college',
#  'enroll counsel',
#  'enroll english',
#  'enroll new',
#  'enroll parent',
#  'enroll school',
#  'enroll summer',
#  'enrollment',
#  'enrollment workshop',
#  'environment',
#  'especially',
#  'especially loses',
#  'establish',
#  'esteem',
#  'esteem family',
#  'esteem issue',
#  'etc',
#  'etiquette',
#  'etiquette social',
#  'even',
#  'ever',
#  'everyday',
#  'everything',
#  'exam',
#  'exam driver',
#  'excessive',
#  'excessive truancy',
#  'excuse',
#  'exhibit',
#  'expect',
#  'expect walk',
#  'expel',
#  'expel school',
#  'expense',
#  'experience',
#  'experience work',
#  'explain',
#  'explain trauma',
#  'explore',
#  'explore educational',
#  'explore post',
#  'explore postsecondary',
#  'explosive',
#  'expose',
#  'expose negative',
#  'express',
#  'express defiant',
#  'express feeling',
#  'express interest',
#  'expunge',
#  'face',
#  'facial',
#  'facial tattoo',
#  'fail',
#  'fail class',
#  'fail school',
#  'fails',
#  'fails finish',
#  'fall',
#  'fall back',
#  'family',
#  'family ask',
#  'family cause',
#  'family come',
#  'family consider',
#  'family counsel',
#  'family currently',
#  'family financial',
#  'family financially',
#  'family grandmother',
#  'family issue',
#  'family know',
#  'family member',
#  'family multigenerational',
#  'family parent',
#  'family problem',
#  'family relation',
#  'family relationship',
#  'family session',
#  'family support',
#  'family tension',
#  'far',
#  'fasfa',
#  'fast',
#  'fast especially',
#  'fast lash',
#  'fast make',
#  'fast peer',
#  'father',
#  'federal',
#  'federal prison',
#  'fee',
#  'feel',
#  'feel stress',
#  'feeling',
#  'felony',
#  'felony record',
#  'female',
#  'female involve',
#  'fight',
#  'fight case',
#  'fight contently',
#  'fight friend',
#  'fight girlfriend',
#  'fight school',
#  'figure',
#  'file',
#  'fill',
#  'finance',
#  'finance home',
#  'financial',
#  'financial aid',
#  'financial challenge',
#  'financial hardship',
#  'financial help',
#  'financial income',
#  'financial issue',
#  'financial literacy',
#  'financial status',
#  'financial support',
#  'financially',
#  'find',
#  'find drinking',
#  'find employment',
#  'find hard',
#  'find housing',
#  'find job',
#  'find part',
#  'find school',
#  'finish',
#  'finish credit',
#  'finish high',
#  'finish school',
#  'finish service',
#  'finish thing',
#  'fire',
#  'first',
#  'first time',
#  'fit',
#  'fit friend',
#  'fit peer',
#  'fit school',
#  'fluent',
#  'focus',
#  'focus keep',
#  'focus pay',
#  'focus school',
#  'follow',
#  'follow direction',
#  'food',
#  'form',
#  'foster',
#  'foster kid',
#  'found',
#  'foundation',
#  'free',
#  'free time',
#  'friend',
#  'friend cause',
#  'friend expose',
#  'friend family',
#  'friend gang',
#  'friend get',
#  'friend influence',
#  'friend make',
#  'friend positive',
#  'friend street',
#  'friend tends',
#  'friendship',
#  ...]

# %%
tfidf_df = pd.DataFrame(X.todense(), 
                        columns=tfidf.get_feature_names())

# %%
tfidf_df.shape
# Out:
# (4039, 2716)

# %%
all(tfidf_df.iloc[16,:]==0)
# Out:
# False

# %%
row1 = tfidf_df.iloc[16,:]
row1[row1 != 0]
# Out:
# anger               0.503842
# anger management    0.614464
# management          0.607106
# Name: 16, dtype: float64

# %% [markdown]
# Implementing K means clustering algorithm

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics
from scipy.spatial.distance import cdist
from sklearn.manifold import TSNE

# %% [markdown]
# Find optimal number of clusters **k**

# %%
pca = PCA(n_components=2, random_state=25)
X_reduced= pca.fit_transform(X.toarray())
distortions = []
K = range(3, 10)
for k in K:
    k_means = KMeans(n_clusters=k, random_state=25).fit(X_reduced)
    k_means.fit(X_reduced)
    distortions.append(sum(np.min(cdist(X_reduced, k_means.cluster_centers_, 'euclidean'), axis=1)) / X.shape[0])

# %%
X_line = [K[0], K[-1]]
Y_line = [distortions[0], distortions[-1]]

# plot elbow method
plt.plot(K, distortions, 'b-')
plt.plot(X_line, Y_line, 'r')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('Finding optimal k using the elbow method')
plt.show()

# %%
k = 5
model = KMeans(n_clusters=k, init='k-means++', max_iter=1000, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=1000,
#        n_clusters=5, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
tsne = TSNE(verbose=1, perplexity=100, random_state=25)
X_embedded = tsne.fit_transform(X.toarray())
# Out:
# [t-SNE] Computing 301 nearest neighbors...
# [t-SNE] Indexed 4039 samples in 0.341s...
# [t-SNE] Computed neighbors for 4039 samples in 67.238s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4039
# [t-SNE] Computed conditional probabilities for sample 2000 / 4039
# [t-SNE] Computed conditional probabilities for sample 3000 / 4039
# [t-SNE] Computed conditional probabilities for sample 4000 / 4039
# [t-SNE] Computed conditional probabilities for sample 4039 / 4039
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 104.032661
# [t-SNE] KL divergence after 1000 iterations: 1.839061

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]

# %%
#order_centroids

# %%
for i in range(k):
    print("Cluster %d:" % i)
    for ind in order_centroids[i, :8]:
        print(' %s' % terms[ind])
# Out:
# Cluster 0:
#  probation
#  school
#  service
#  assistance
#  id
#  job
#  work
#  currently
# Cluster 1:
#  look
#  look employment
#  employment
#  look work
#  work
#  job
#  currently look
#  look get
# Cluster 2:
#  anger
#  issue
#  anger issue
#  anger management
#  management
#  family issue
#  family
#  management class
# Cluster 3:
#  employment
#  employment search
#  assistance employment
#  search
#  assistance
#  seek assistance
#  seek
#  assitance employment
# Cluster 4:
#  avoid
#  street affiliation
#  street
#  problem street
#  interpersonal
#  affiliation
#  navagate
#  potential

# %%
y_pred = model.fit_predict(X)

# %%
len(y_pred)
# Out:
# 4039

# %%
df['Problem_Classification'] = y_pred
#df.drop('Classification', axis=1, inplace=True)

# %%
df.Problem_Classification.value_counts()
# Out:
# 0    2990
# 2     499
# 1     249
# 4     191
# 3     110
# Name: Problem_Classification, dtype: int64

# %%
#0: Emotional and behavior issues (peer pressure, anger management issues, family issues, toxic relationships, improper/anti-social behavior etc)
#1: Need assistance with employment search
#2: Need work ready documents/California id
#3: Need mentoring from CM/CIW to navigate interpersonal relationships and avoid potential problems with street affiliations
#4: Need assistance with school enrollment/improving school grades
#5: Need to complete community service hours for probation requirements

# %%
#df[df['Problem_Classification']==0]['Problem'].value_counts()

# %%
#labels = {0:'need service to navagate interpersonal relationship', 1:'need complete service', 
          #2:'employment related issue', 3:'need substance abuse class', 4:'anger issue',
          #5:'gang related issue'}
labels = {0:'Emotional/behavior issues', 
          1:'Need assistance with employment search', 
          2:'Need work ready documents/California id', 
          3:'Need mentoring to navigate interpersonal relationships',
          4:'Need assistance with school enrollment', 
          5:'Need to complete community service hours'}

# %%
# short label
labels = {0:'Emotional/behavior issues', 
          1:'Employment related issues', 
          2:'Lack work ready documents/CA ID', 
          3:'Interpersonal relationship issues',
          4:'School related issues', 
          5:'Probation related issues'}

# %%
# DON'T RUN
labels = {0:"developmental asset", 1:"support/mentor", 2:"get ready for work/school", 
         3: "life skill/anger management", 4:"counseling (employment etc)",
         5:'substance abuse class',
         6: 'sixth',
         7:'seventh'}

# %%
df["Problem_Label"] = df["Problem_Classification"].map(labels)

# %%
df.head()
# Out:
# 1               ID                                            Problem  \
# 5   77th 1-16-40-2                        wants to expunge her record
# 6   77th 1-16-45-1  needs a job client is a foster kid and her fos...
# 7   77th 1-16-47-2      has poor grades and want to get better grades
# 8   77th 1-16-50-2                    client don't believe in herself
# 13  77th 1-16-64-1  client has a lot of issues he is a foster kid ...
#
# 1                                            Strategy  \
# 5   CM will contact past employers with client to ...
# 6   speak to teacher about mother and refer client...
# 7   CM will work on getting tutoring services alon...
# 8   to mentor client with basic life skills and se...
# 13  referred him to in-house services through SEA ...
#
# 1                              Progress  Problem_Classification  \
# 5   Task/Service successfully completed                       0
# 6   Task/Service successfully completed                       0
# 7    N/A - not applicable to this phase                       0
# 8                     A Little progress                       0
# 13                    A Little progress                       0
#
# 1               Problem_Label
# 5   Emotional/behavior issues
# 6   Emotional/behavior issues
# 7   Emotional/behavior issues
# 8   Emotional/behavior issues
# 13  Emotional/behavior issues

# %%
color_dict = dict({'Emotional/behavior issues':'dodgerblue',
                  'Need assistance with employment search':'forestgreen',
                  'Need work ready documents/California id': 'orange',
                  'Need mentoring to navigate interpersonal relationships': 'springgreen',
                  'Need assistance with school enrollment': 'yellow',
                  'Need to complete community service hours': 'red'})

# %%
import matplotlib.pyplot as plt
import seaborn as sns
X_embedded_all = X_embedded

sns.set(rc={'figure.figsize':(10,10)})


color_dict = dict({'Emotional/behavior issues':'dodgerblue',
                  'Employment related issues':'forestgreen',
                  'Lack work ready documents/CA ID': 'orange',
                  'Interpersonal relationship issues': 'springgreen',
                  'School related issues': 'yellow',
                  'Probation related issues': 'red'})
                  #'sixth':'yellow',
        
                  


sns.scatterplot(X_embedded_all[:,0], X_embedded_all[:,1], hue=df['Problem_Label'].values, legend='full', palette=color_dict)
plt.title('Strategies with {} clusters'.format(k))
plt.show()

# %%
df.to_csv('Problems_and_Strategies_with_labels2.csv', index=False)

# %%
df['Strategy_Label'].value_counts()
